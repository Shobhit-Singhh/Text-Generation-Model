# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('punkt')
import gensim
from gensim.models import Word2Vec
import nltk
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
corpus = """Once upon a time, in a bustling city named Technopolis, lived a young woman named Aria. She was an inventive and curious soul, always eager to learn and explore new ideas. Her apartment was a reflection of her mind—cluttered with books, gadgets, and sketches of futuristic designs. Aria worked as a data scientist at a renowned tech company, InnovateX, where she was known for her unique approach to problem-solving.

One morning, while sipping her coffee and scrolling through her emails, Aria received a message from her boss, Mr. Reynolds. He had an exciting yet challenging project for her: to develop an AI system capable of predicting and preventing equipment failures in the city's intricate network of automated public transport. This system was vital for maintaining the smooth flow of Technopolis, a city heavily reliant on its transport network.

Aria’s mind buzzed with ideas. She immediately began her research, diving deep into the world of machine learning and predictive analytics. She spent hours poring over historical data, identifying patterns, and developing algorithms. Her dedication was unwavering, but the task was daunting. She knew she needed help.

Enter Max, her quirky yet brilliant colleague. Max was a master of software engineering and shared Aria’s passion for innovation. Together, they formed a formidable team, brainstorming and collaborating late into the night. They built a prototype system that collected real-time data from sensors installed in the transport vehicles and infrastructure. This data included everything from temperature and vibration levels to engine performance metrics.

Aria and Max’s system, named ProGuard, used advanced machine learning models to analyze the data, identify anomalies, and predict potential failures before they occurred. They implemented a sophisticated alert mechanism that notified maintenance crews instantly, allowing them to take preventive action. The project was progressing well, but they faced a significant challenge: making the system adapt to the dynamic and ever-changing environment of Technopolis.

One evening, while Aria was reviewing the system’s performance metrics, she had a revelation. She realized that incorporating reinforcement learning could enable ProGuard to adapt and improve over time. Excitedly, she shared her idea with Max, who immediately saw the potential. They worked tirelessly to integrate this new approach, tweaking and fine-tuning their models.

As the weeks passed, ProGuard became increasingly effective. It could predict equipment failures with remarkable accuracy, reducing downtime and ensuring the transport network operated seamlessly. The city’s officials were impressed and decided to implement ProGuard citywide.

On the day of the system’s official launch, Technopolis was abuzz with anticipation. Aria and Max stood side by side, watching as the mayor activated ProGuard. Instantly, the system sprang to life, its algorithms analyzing streams of data and issuing alerts as needed. The launch was a resounding success, and Aria and Max were hailed as heroes.

With ProGuard in place, the citizens of Technopolis enjoyed a new level of convenience and reliability in their daily commutes. Aria and Max continued to refine and expand the system, always striving for perfection. Their success story inspired many young innovators in the city, proving that with curiosity, collaboration, and determination, even the most daunting challenges could be overcome.

And so, Aria’s journey as a data scientist became a beacon of inspiration, reminding everyone in Technopolis that the future was bright and full of endless possibilities. Months passed, and ProGuard's success continued to shine throughout Technopolis. The city became a model for urban efficiency and innovation, attracting attention from global tech leaders and urban planners. Aria and Max, now local celebrities, found themselves invited to conferences and think tanks, sharing their insights and experiences.

One day, as Aria was preparing for a keynote speech, she received a mysterious letter. It was from a remote village named Verdantia, nestled deep within a lush forest far from the hustle and bustle of Technopolis. The village head, an elderly man named Eamon, had heard of ProGuard and sought Aria’s help. Verdantia was facing a crisis: their ancient irrigation system was failing, and the crops were withering, threatening the village’s survival.

Intrigued by the challenge and moved by the villagers' plight, Aria decided to visit Verdantia. She persuaded Max to join her, and together, they embarked on a journey to the remote village. As they traveled deeper into the forest, the air grew fresher, and the sounds of nature replaced the constant hum of the city. Verdantia, with its quaint cottages and verdant fields, seemed like a world apart.

Eamon greeted them warmly and led them to the heart of the village, where the irrigation system lay. It was a complex network of wooden channels and ancient machinery, clearly in need of an upgrade. Aria and Max set to work immediately, examining the system and gathering data. They realized that while the technology was old, it had a certain charm and resilience that modern systems lacked.

Aria proposed a hybrid solution that would blend modern technology with the traditional system. They installed sensors to monitor water levels, soil moisture, and weather conditions. Using solar-powered devices, they ensured the system remained sustainable and environmentally friendly. They also developed an AI algorithm tailored to Verdantia’s unique needs, predicting weather patterns and optimizing water distribution to the crops.

The project was challenging, but Aria and Max thrived on the sense of purpose and community they found in Verdantia. The villagers, initially skeptical, began to trust and support them, providing invaluable local knowledge and assistance. Children gathered around, fascinated by the technology and eager to learn.

As weeks turned into months, the irrigation system, now called EcoFlow, began to show results. The fields turned green again, and the crops flourished. The villagers rejoiced, celebrating the revival of their lifeline. Aria and Max had not only saved the village but had also created a sustainable model that could be replicated in other rural areas.

One evening, as the villagers gathered for a feast to honor their efforts, Eamon approached Aria and Max. He thanked them for their ingenuity and compassion, presenting them with handcrafted wooden plaques as tokens of gratitude. Aria felt a deep sense of fulfillment, knowing they had made a real difference.

As they prepared to return to Technopolis, Aria and Max reflected on their journey. They realized that true innovation wasn’t just about advanced technology but about understanding and respecting the unique needs and wisdom of different communities. They returned to the city with renewed inspiration and a commitment to using their skills for the greater good.

Back in Technopolis, Aria and Max continued to innovate, working on projects that bridged the gap between urban and rural, modern and traditional. They collaborated with other villages, sharing their knowledge and helping them implement sustainable solutions. Their work led to the formation of a new initiative, Tech4All, dedicated to bringing cutting-edge technology to underserved communities.

Aria’s story spread far and wide, inspiring countless individuals to pursue innovation with empathy and purpose. Her journey from the bustling streets of Technopolis to the serene fields of Verdantia became a testament to the transformative power of technology when paired with human compassion and ingenuity. And so, Aria’s legacy grew, leaving an indelible mark on the world, one community at a time. With Tech4All gaining momentum, Aria and Max found themselves at the forefront of a movement that was changing lives across regions. Their initiative not only brought technological advancements to rural areas but also fostered a sense of unity and collaboration among diverse communities.

One of their most ambitious projects was in the desert town of Solara. Solara had abundant sunlight but lacked sufficient water resources and infrastructure to harness solar energy efficiently. The town’s residents relied on expensive and polluting diesel generators for electricity, which was unsustainable and harmful to their health.

Aria and Max saw an opportunity to transform Solara into a model of sustainable living. They assembled a team of experts in renewable energy, water management, and community development. Together, they devised a comprehensive plan to address Solara’s challenges.

Their first step was to install a network of solar panels throughout the town, capable of providing clean and reliable energy to all households and businesses. These panels were connected to a central smart grid that optimized energy distribution and storage, ensuring that excess energy was stored for use during the night or cloudy days. The team also introduced solar-powered water pumps and desalination units, enabling the extraction and purification of water from underground sources and nearby saline bodies.

As the solar infrastructure took shape, Aria and Max focused on engaging the local community. They organized workshops to educate residents about the benefits of renewable energy and sustainable practices. These sessions covered everything from maintaining the solar panels to water conservation techniques. The residents of Solara, initially hesitant, gradually embraced the changes, driven by the promise of a better, healthier future.

The transformation of Solara was nothing short of miraculous. Within months, the town’s reliance on diesel generators plummeted, replaced by the clean, inexhaustible power of the sun. The new water infrastructure not only provided fresh drinking water but also supported agriculture, allowing the community to grow crops that were previously impossible in the arid environment.

With Solara thriving, Aria and Max turned their attention to another pressing issue: education. They realized that access to quality education was crucial for sustainable development and sought to create a network of digital learning centers in remote areas.

Their first pilot project was in the mountainous region of Auralia, where schools were scarce and students had to travel long distances to receive basic education. Aria and Max partnered with educational institutions and tech companies to develop portable digital classrooms equipped with tablets, projectors, and solar-powered charging stations.

These digital classrooms were designed to be mobile, capable of reaching even the most isolated villages. The tablets came preloaded with interactive learning modules, covering a wide range of subjects and levels. Additionally, they implemented a satellite-based internet system to ensure connectivity, enabling students to access online resources and communicate with teachers and peers from around the world.

The impact in Auralia was profound. Children who had never seen a computer before were now coding, exploring virtual labs, and engaging in global discussions. The digital classrooms brought a new world of possibilities, igniting a passion for learning and discovery among the students.

The success of the digital learning centers inspired Tech4All to expand the initiative to other regions. They launched similar projects in remote coastal villages, dense rainforests, and arid plains, adapting the technology to suit the unique needs and challenges of each area.

As Tech4All continued to grow, Aria and Max remained deeply involved, constantly seeking innovative solutions and partnerships. They collaborated with universities, NGOs, and governments, leveraging their collective expertise and resources to maximize their impact.

One of their most notable partnerships was with the Global Health Alliance (GHA), an international organization dedicated to improving healthcare in underserved communities. Together, they launched the TechHealth initiative, aimed at bringing advanced medical technology and services to remote areas.

TechHealth’s flagship project was in the remote island community of Oceania, where access to healthcare was limited, and residents often faced long journeys to the nearest medical facility. Aria and Max, along with the GHA team, introduced telemedicine units and portable diagnostic devices, allowing residents to receive medical consultations and treatments without leaving their island.

The telemedicine units connected patients with doctors from around the world, providing timely diagnoses and medical advice. The portable diagnostic devices, designed to be user-friendly, enabled local health workers to perform essential tests and monitor chronic conditions. This combination of technology and local knowledge dramatically improved healthcare outcomes, reducing mortality rates and enhancing the overall quality of life.

As TechHealth expanded, Aria and Max saw the potential for even greater impact. They explored the use of AI in healthcare, developing predictive models to identify disease outbreaks and optimize resource allocation. They also introduced AI-powered diagnostic tools that could analyze medical images and data with remarkable accuracy, supporting healthcare professionals in making informed decisions.

Throughout their journey, Aria and Max never lost sight of the core values that drove their work: empathy, collaboration, and sustainability. They believed that technology, when used thoughtfully and inclusively, could bridge gaps and build a better world for all.

Their dedication earned them numerous accolades and recognition. They were invited to speak at international forums, where they shared their experiences and inspired others to pursue similar initiatives. Their story became a symbol of hope and possibility, demonstrating that with passion and perseverance, even the most daunting challenges could be overcome.

As Aria and Max looked back on their journey, they felt a deep sense of fulfillment. They had started with a simple idea—to use their skills to make a difference—and had created a movement that touched lives across the globe. Their work was far from over, but they knew that together, they could continue to push the boundaries of what was possible.

In Technopolis, Verdantia, Solara, Auralia, Oceania, and countless other places, the legacy of Aria and Max lived on. Their projects continued to evolve and grow, driven by the communities they served and the countless individuals they inspired. And as new challenges arose, they stood ready, armed with the knowledge that innovation, guided by empathy and collaboration, could indeed change the world."""

# %%
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in nltk.sent_tokenize(corpus.lower())]

# Train Word2Vec model
word2vec_model = Word2Vec(sentences=tokenized_sentences, vector_size=1000, window=10, min_count=1, workers=4)

# Function to embed a sentence
def embed_sentence(sentence, model):
    return [model.wv[word] for word in nltk.word_tokenize(sentence) if word in model.wv]

# Embed all sentences
embedded_sentences = [embed_sentence(' '.join(sentence), word2vec_model) for sentence in tokenized_sentences]

# Create sequences from pre-embedded sentences
def create_sequences(embedded_sentences, sequence_length):
    X = []
    y = []
    for sentence in embedded_sentences:
        if len(sentence) <= sequence_length:
            continue
        for i in range(len(sentence) - sequence_length):
            sequence = sentence[i:i + sequence_length]
            next_word = sentence[i + sequence_length]
            X.append(sequence)
            y.append(next_word)
    return np.array(X), np.array(y)

sequence_length = 10
X, y = create_sequences(embedded_sentences, sequence_length)

# Debugging: Print the shapes of X and y
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

X_padded = pad_sequences(X, maxlen=sequence_length, dtype='float32', padding='post')
y_padded = np.array(y)

# Debugging: Print the shapes of X_padded and y_padded
print(f"Shape of X_padded: {X_padded.shape}")
print(f"Shape of y_padded: {y_padded.shape}")

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_padded, test_size=0.2, random_state=42)

# Define model creation functions
def create_simple_rnn_model(input_shape, optimizer):
    model = Sequential()
    model.add(SimpleRNN(100, input_shape=input_shape))
    model.add(Dense(word2vec_model.vector_size, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

def create_lstm_model(input_shape, optimizer):
    model = Sequential()
    model.add(LSTM(100, input_shape=input_shape))
    model.add(Dense(word2vec_model.vector_size, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

def create_gru_model(input_shape, optimizer):
    model = Sequential()
    model.add(GRU(100, input_shape=input_shape))
    model.add(Dense(word2vec_model.vector_size, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

# Function to train and evaluate model
def train_and_evaluate(model, X_train, y_train, X_test, y_test, optimizer_name, model_name):
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f'{model_name} with {optimizer_name}: Loss = {loss}, Accuracy = {accuracy}')
    return history

# Train models with different optimizers
optimizers = ['adam', 'sgd', 'rmsprop']
input_shape = (sequence_length, word2vec_model.vector_size)

# Dictionary to store history
histories = {}

for model_name, model_func in [('SimpleRNN', create_simple_rnn_model),
                                ('LSTM', create_lstm_model),
                                ('GRU', create_gru_model)]:
    for optimizer in optimizers:
        print(f"Training {model_name} with {optimizer} optimizer.")
        model = model_func(input_shape, optimizer)
        history = train_and_evaluate(model, X_train, y_train, X_test, y_test, optimizer, model_name)
        histories[f'{model_name}_{optimizer}'] = history

# Plotting
def plot_history(histories, metric='loss'):
    plt.figure(figsize=(12, 8))
    for key in histories:
        plt.plot(histories[key].history[metric], label=key)
    plt.title(f'Model {metric} comparison')
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.show()

# Plot loss and accuracy
plot_history(histories, 'loss')
plot_history(histories, 'accuracy')
# Out:
# Shape of X: (1295, 10, 1000)
# Shape of y: (1295, 1000)
# Shape of X_padded: (1295, 10, 1000)
# Shape of y_padded: (1295, 1000)
# Training SimpleRNN with adam optimizer.
# Epoch 1/20
# 26/26 [==============================] - 2s 28ms/step - loss: 2.9790e-06 - accuracy: 0.0024 - val_loss: 1.9336e-06 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 26/26 [==============================] - 0s 15ms/step - loss: 1.7579e-06 - accuracy: 0.0145 - val_loss: 1.6238e-06 - val_accuracy: 0.0240
# Epoch 3/20
# 26/26 [==============================] - 0s 17ms/step - loss: 1.5207e-06 - accuracy: 0.0133 - val_loss: 1.4729e-06 - val_accuracy: 0.0096
# Epoch 4/20
# 26/26 [==============================] - 0s 16ms/step - loss: 1.4007e-06 - accuracy: 0.0145 - val_loss: 1.3805e-06 - val_accuracy: 0.0096
# Epoch 5/20
# 26/26 [==============================] - 0s 14ms/step - loss: 1.3194e-06 - accuracy: 0.0290 - val_loss: 1.3053e-06 - val_accuracy: 0.0433
# Epoch 6/20
# ...

# %%
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in nltk.sent_tokenize(corpus.lower())]

# Train Word2Vec model
word2vec_model = Word2Vec(sentences=tokenized_sentences, vector_size=1000, window=10, min_count=1, workers=4)

# Function to embed a sentence
def embed_sentence(sentence, model):
    return [model.wv[word] for word in nltk.word_tokenize(sentence) if word in model.wv]

# Embed all sentences
embedded_sentences = [embed_sentence(' '.join(sentence), word2vec_model) for sentence in tokenized_sentences]

# Create sequences from pre-embedded sentences
def create_sequences(embedded_sentences, sequence_length):
    X = []
    y = []
    for sentence in embedded_sentences:
        if len(sentence) <= sequence_length:
            continue
        for i in range(len(sentence) - sequence_length):
            sequence = sentence[i:i + sequence_length]
            next_word = sentence[i + sequence_length]
            X.append(sequence)
            y.append(next_word)
    return np.array(X), np.array(y)

sequence_length = 10
X, y = create_sequences(embedded_sentences, sequence_length)

# Debugging: Print the shapes of X and y
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

X_padded = pad_sequences(X, maxlen=sequence_length, dtype='float32', padding='post')
y_padded = np.array(y)

# Debugging: Print the shapes of X_padded and y_padded
print(f"Shape of X_padded: {X_padded.shape}")
print(f"Shape of y_padded: {y_padded.shape}")

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_padded, test_size=0.2, random_state=42)

# Define model creation functions
def create_simple_rnn_model(input_shape, optimizer):
    model = Sequential()
    model.add(SimpleRNN(100, input_shape=input_shape))
    model.add(Dense(word2vec_model.vector_size, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

def create_lstm_model(input_shape, optimizer):
    model = Sequential()
    model.add(LSTM(100, input_shape=input_shape))
    model.add(Dense(word2vec_model.vector_size, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

def create_gru_model(input_shape, optimizer):
    model = Sequential()
    model.add(GRU(100, input_shape=input_shape))
    model.add(Dense(word2vec_model.vector_size, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

# Function to train and evaluate model
def train_and_evaluate(model, X_train, y_train, X_test, y_test, optimizer_name, model_name):
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f'{model_name} with {optimizer_name}: Loss = {loss}, Accuracy = {accuracy}')
    return history

# Train models with different optimizers
optimizers = ['rmsprop']
input_shape = (sequence_length, word2vec_model.vector_size)

# Dictionary to store history
histories = {}

for model_name, model_func in [('LSTM', create_lstm_model),
                                ('GRU', create_gru_model)]:
    for optimizer in optimizers:
        print(f"Training {model_name} with {optimizer} optimizer.")
        model = model_func(input_shape, optimizer)
        history = train_and_evaluate(model, X_train, y_train, X_test, y_test, optimizer, model_name)
        histories[f'{model_name}_{optimizer}'] = history

# Plotting
def plot_history(histories, metric='loss'):
    plt.figure(figsize=(12, 8))
    for key in histories:
        plt.plot(histories[key].history[metric], label=key)
    plt.title(f'Model {metric} comparison')
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.show()

# Plot loss and accuracy
plot_history(histories, 'loss')
plot_history(histories, 'accuracy')
# Out:
# Shape of X: (1295, 10, 1000)
# Shape of y: (1295, 1000)
# Shape of X_padded: (1295, 10, 1000)
# Shape of y_padded: (1295, 1000)
# Training LSTM with rmsprop optimizer.
# Epoch 1/100
# 26/26 [==============================] - 5s 80ms/step - loss: 6.8456e-07 - accuracy: 0.0072 - val_loss: 6.5311e-07 - val_accuracy: 0.0481
# Epoch 2/100
# 26/26 [==============================] - 1s 56ms/step - loss: 6.2093e-07 - accuracy: 0.1425 - val_loss: 6.0393e-07 - val_accuracy: 0.2644
# Epoch 3/100
# 26/26 [==============================] - 2s 58ms/step - loss: 5.8320e-07 - accuracy: 0.3297 - val_loss: 5.7247e-07 - val_accuracy: 0.4038
# Epoch 4/100
# 26/26 [==============================] - 1s 53ms/step - loss: 5.5859e-07 - accuracy: 0.3816 - val_loss: 5.5091e-07 - val_accuracy: 0.4375
# Epoch 5/100
# 26/26 [==============================] - 1s 29ms/step - loss: 5.4184e-07 - accuracy: 0.4106 - val_loss: 5.3594e-07 - val_accuracy: 0.4663
# Epoch 6/100
# ...
